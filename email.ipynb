# %%
# Email Slicer Program

email = input("Enter your email address: ").strip()

# Find position of '@'
at_index = email.index('@')

# Slice username and domain
username = email[:at_index]
domain = email[at_index + 1:]

# Output results
print("Username:", username)
print("Domain:", domain)
# Out:
# Username: kambaranil957
# Domain: gmail.com
