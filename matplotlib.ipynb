# %%
# Matplotlib tutorial: matplotlib is a plotting library for the python programming language and its numerical mathematics extension NumPy. It provides an object oriented API for embedding plots into applications using general-purpose GUI toolkits like Tkinter,wxPython, Qt, or GTK+.
#  some of the major pros of matplotlib are:
   # Generally easy to get started for simple plots
   # Support for custom labels and texts
   # Great control of every element in a figure
   # High-quality output in many formats
   # Very customizable in general

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np

# %%
# simple examples taking two variables

x=np.arange(0,10)
y=np.arange(11,21)

# %%
a=np.arange(40,50)
b=np.arange(50,60)

# %%
## plotting using matplotlib
## plt scatter
## if we not write %matplotlib inline then we write every time plt.show()

plt.scatter(x,y,c='b')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
# Out:
# Text(0.5, 1.0, 'Graph in 2D')

# %%
plt.scatter(x,y,c='g')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph in 2D')
plt.savefig('Test.png')

# %%
y=x*x

# %%
## plt plot
plt.plot(x,y,c='r')

# %%
plt.plot(x,y,'r--')

# %%
plt.plot(x,y,'r*')

# %%
plt.plot(x,y,'ro--')

# %%
## plt.plot

plt.plot(x,y,'r*',linestyle='dashed',linewidth=2,markersize=12)
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('2D Diagram')
# Out:
# Text(0.5, 1.0, '2D Diagram')

# %%
## creating subplots

plt.subplot(2,2,1)
plt.plot(x,y,'ro')
plt.subplot(2,2,2)
plt.plot(x,y,'g--')
plt.subplot(2,2,3)
plt.plot(x,y,'b*')
plt.subplot(2,2,4)
plt.plot(x,y,'g*-')

# %%
x=np.arange(1,11)
y=3*x+5
plt.title("Matplotlib demo")
plt.xlabel("x axis caption")
plt.ylabel("y  axis caption")
plt.plot(x,y)
plt.show()

# %%
np.pi
# Out:
# 3.141592653589793

# %%
## compute the x and y coordinates for points on a sine curve

x=np.arange(0, 4*np.pi, 0.1)
y=np.sin(x)
plt.title("sine wave form")

#plot the points using matplotlib
plt.plot(x,y,'b')
plt.show()

# %%
# compute the x and y coordinates for points on sine and cosine curves
x=np.arange(0,5*np.pi,0.1)
y_sin=np.sin(x)
y_cos=np.cos(x)

# set up a subplot grid that has height 2 and width 1,
# and set the first such subplot as active
plt.subplot(2,1,1)

# make the first plot
plt.plot(x,y_sin,'r--')
plt.title('Sine')

# set the second subplot as active ,and make the second plot.
plt.subplot(2,1,2)
plt.plot(x,y_cos,'b*')
plt.title('Cosine')
# show the figure.
plt.show()

# %%
## Bar plot

x=[2,8,10]
y=[11,16,9]

x2=[3,9,11]
y2=[6,15,7]
plt.bar(x,y,color='b')
plt.bar(x2,y2,color='g')
plt.title('Bar graph')
plt.ylabel('Y axis')
plt.xlabel('x axis')
plt.show()

# %%
# histograms

# %%
a= np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
plt.hist(a,bins=20)       #bins specify the density of particular number that we can find out in particular array
plt.title("Histogram")
plt.show()
