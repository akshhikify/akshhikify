# %%
## Logarithmic Time (o(log n))

n=1000
while n>0:
    print(n, end=" ")
    n//=2
# Out:
# 1000 500 250 125 62 31 15 7 3 1

# %%
i=1
n=100
while i<=n:
    print(i, end=" ")
    i*=2
# Out:
# 1 2 4 8 16 32 64

# %%
## Exponential  Time (O(2^n))
# Comparison of time Complexities
# O(1)<O(log n)<O(n)<O(n log n)<O(n^2)<O(2^n)<O(n!)

# %%
## Space Complexity: Space Complexity refers to the amount of memory an algorithm uses as a function of the input size. It's a+ measure of how much memory an algorithm requires to execute and solve a problem.

n=100
m=10

list1=[0]*10

for i in range(n):
    list1.append(m)

# %%
# Introduction to recursion: The process in which a function calls itself directly or indirectly is called recursion and the corresponding function is called a recursive function.

# %%
# Loop vs Recursion:

n=5
i=1
while i<=n:
    print(i, end=" ")
    i+=1
# Out:
# 1 2 3 4 5

# %%
def printNumbers(i,n):
    # base case
    if i>n:
        return
    # recursive case
    print(i, end=" ")
    printNumbers(i+1,n)

printNumbers(1,5)
# Out:
# 1 2 3 4 5
