# %%
# Basics DSA with Python
#1. what is Python?
#2. high level language and low level language
#3. compiler and interpreter
#4. Introduction to Python
#5. Variables,keywords, Identifiers, Comments
#6. Operators

# %%
print("Hello world")
# Out:
# Hello world

# %%
monday=87
tuesday=64
avg=(monday+tuesday)/2
print(avg)

# %% [markdown]
# #### variables/ keywords/ Identifiers/ comments

# %%
# This program finds th
# average attendance od
# monday and tuesday
monday = 87
tuesday = 64
avg = (monday + tuesday) / 2
print(avg)
# Out:
# 75.5

# %%
""" This program finds th
 average attendance od
 monday and tuesday"""
monday = 87
tuesday = 64
avg = (monday + tuesday) / 2
print(avg)
# Out:
# 75.5

# %%
## Arithmatic operator
print(56+43)
# Out:
# 99

# %%
print(20-10)
print(23*2)
print(12/2)
print(34//2)
print(34%3)
print(2**3)
# Out:
# 10
# 46
# 6.0
# 17
# 1
# 8

# %%
# assignment operator
a=5
a+=2
a*=3

print(a)
# Out:
# 21
