# %%
def decorator_function(original_function):
    def wrapper_function():
        print("Before execution")
        original_function()
        print("After execution")
    return wrapper_function


def say_hello():
    print("Hello!")

decorated = decorator_function(say_hello)
decorated()
# Out:
# Before execution
# Hello!
# After execution

# %%
## Closures
def main_welcome(msg):
    def sub_welcome_class():
        print("Welcome to aksh youtube channel")
        print(msg)
        print("please subscribe aksh channel")
    return sub_welcome_class()

# %%
main_welcome("aksh")
# Out:
# Welcome to aksh youtube channel
# aksh
# please subscribe aksh channel

# %%
## closures and initial Decorators
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome to aksh youtube channel")
        func("This Youtube channel deals with programming")
        print("please subscribe aksh channel")
    return sub_welcome_class()

# %%
main_welcome(len)
# Out:
# Welcome to aksh youtube channel
# please subscribe aksh channel

# %%
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome to aksh youtube channel")
        print(func([1,2,3,4,5,6]))
        print("please subscribe aksh channel")
    return sub_welcome_class()

# %%
len([1,2,3,4,5,6,7])
# Out:
# 7

# %%
def main_welcome(func):
    def sub_welcome_class():
        print("Welcome to aksh youtube channel")
        func()
        print("please subscribe aksh channel")
    return sub_welcome_class()

# %%
def channel_name():
    print("This is aksh youtube channel")

# %%
main_welcome(channel_name)
# Out:
# Welcome to aksh youtube channel
# This is aksh youtube channel
# please subscribe aksh channel

# %% [markdown]
# ## is vs ==

# %%
### is vs ==
lst1=["krish","krish2","krish3"]
lst2=["krish","krish2","krish3"]
lst1==lst2
# Out:
# True

# %%
a="krish"
b="krish"
a==b
# Out:
# True

# %%
lst1 = ["krish", "krish2", "krish3"]
lst2 = lst1
lst1 is lst2
# Out:
# True

# %%
lst2 is lst1
# Out:
# True
