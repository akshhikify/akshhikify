# %%
class Car:
    def __init__(self,window,door,engintype):
        self.window=window
        self.door=door
        self.engintype=engintype
    def self_driving(self,engintype):
        return "This is a {} car".format(self.engintype)

# %%
car1=Car(4,5,"petrol")

# %%
class Car:
    pass

# %%
dir(car1)  # inbuilt
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'doors',
#  'windows']

# %%
car1=Car()

# %%
car1

# %%
car1.windows=5
car1.doors=4

# %%
print(car1.windows)
# Out:
# 5

# %%
car2=Car()

# %%
car2.windows=3
car2.doors=2

# %%
print(car2.windows)
# Out:
# 3

# %%
car2.engintype="petrol"

# %%
print(car2.engintype)
# Out:
# petrol
